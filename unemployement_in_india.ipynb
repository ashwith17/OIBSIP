# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_csv('Unemployment in India.csv')

# %%
df.head(5)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
df.count()
# Out:
# Region                                      740
#  Date                                       740
#  Frequency                                  740
#  Estimated Unemployment Rate (%)            740
#  Estimated Employed                         740
#  Estimated Labour Participation Rate (%)    740
# Area                                        740
# dtype: int64

# %%
df=df.dropna()

# %%
df.sort_index()
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df=df.reindex(np.arange(len(df.index)))

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 735     Uttarakhand   29-02-2020    Monthly                              5.28
# 736     Uttarakhand   31-03-2020    Monthly                              8.15
# 737     Uttarakhand   30-04-2020    Monthly                             13.18
# 738     Uttarakhand   31-05-2020    Monthly                             17.36
# 739     Uttarakhand   30-06-2020    Monthly                              5.08
#
# ...

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data=df,x=' Estimated Unemployment Rate (%)',hue='Area')
# Out:
# <AxesSubplot:xlabel=' Estimated Unemployment Rate (%)', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
sns.histplot(data=df,x=' Estimated Employed',hue='Area')
# Out:
# <AxesSubplot:xlabel=' Estimated Employed', ylabel='Count'>

# %%
sns.histplot(data=df,x=' Estimated Labour Participation Rate (%)',hue='Area')
# Out:
# <AxesSubplot:xlabel=' Estimated Labour Participation Rate (%)', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sns.histplot(data=df,x=' Estimated Labour Participation Rate (%)',hue='Region')
# Out:
# <AxesSubplot:xlabel=' Estimated Labour Participation Rate (%)', ylabel='Count'>

# %%
plt.figure(figsize=(12,12))
sns.histplot(data=df,x=' Estimated Employed',hue='Region')
# Out:
# <AxesSubplot:xlabel=' Estimated Employed', ylabel='Count'>

# %%
plt.figure(figsize=(12,12))
sns.histplot(data=df,x=' Estimated Unemployment Rate (%)',hue='Region')
# Out:
# <AxesSubplot:xlabel=' Estimated Unemployment Rate (%)', ylabel='Count'>
